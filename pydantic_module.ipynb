# %%
from time import struct_time

from pydantic import BaseModel

# %%
class Person(BaseModel):
    name: str
    age: int
    city:str

person = Person(name="Anmol", age=22, city = "Bhopal")

# %%
person
# Out:
# Person(name='Anmol', age=22, city='Bhopal')

# %%
person2= Person(name="Anmol", age=22, city = "23")
print (person2)
# Out:
# name='Anmol' age=22 city='23'

# %%
from typing import Optional as op
class employee(BaseModel):
    id :int
    name:str
    department:str
    salary:op[float] = None
    is_active:op[bool] = None

# %%
emp1 = employee(id = 12 , name= "jony" , department="cse", salary= 23333.56 , is_active = True)

# %%
emp2 = employee(id = 12 , name= "jony" , department="cse", salary= 23333.56 )

# %%
emp3 = employee(id = 12 , name= "jony" , department="cse" )

# %%
print(emp1)
# Out:
# id=12 name='jony' department='cse' salary=23333.56 is_active=True

# %%
print(emp2)
# Out:
# id=12 name='jony' department='cse' salary=23333.56 is_active=None

# %%
print(emp3)
# Out:
# id=12 name='jony' department='cse' salary=None is_active=None

# %%
class Classroom(BaseModel):
    room_no: int
    name: list[str]
    capacity : int

# %%
cl1 = Classroom(
    room_no = 12 ,
    name = ("pinku", "shyenki", "jayesh"),
    capacity = 30
)

# %%
print (cl1 )
# Out:
# room_no=12 name=['pinku', 'shyenki', 'jayesh'] capacity=30

# %%
try:
    invalid_cl = Classroom(room_no=12, name=["pinku", 123 , "risadh"], capacity=30)

except ValueError as e:
    print(e)
# Out:
# 1 validation error for Classroom
# name.1
#   Input should be a valid string [type=string_type, input_value=123, input_type=int]
#     For further information visit https://errors.pydantic.dev/2.12/v/string_type

# %% [markdown]
# # create complex nested model

# %%
from pydantic import BaseModel

class Address(BaseModel):
    street: str
    city: str
    zip_code: str

class Customer(BaseModel):
    customer_id: int
    name: str
    address: Address

# Create customer
customer = Customer(
    customer_id=1,
    name="Emma",
    address={
        "street": "123 Main St",
        "city": "Boston",
        "zip_code": "02108"
    }
)

print(customer)
# Out:
# customer_id=1 name='Emma' address=Address(street='123 Main St', city='Boston', zip_code='02108')

# %% [markdown]
# # Customizaton and constraint

# %%
from pydantic import BaseModel , Field
class  item(BaseModel):
    name:str =Field(min_length =2 , max_length=100)
    price:float =Field(gt =0, le=1000)
    quantity:int =Field(gt=0)

# %%
it1 = item(name = "book", price= 23.56, quantity=3)

# %%
print(it1 )
# Out:
# name='book' price=23.56 quantity=3

# %%
it2 = item(name = "book", price= 223.56, quantity=3)

# %%
print(it2 )
# Out:
# name='book' price=223.56 quantity=3
